# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')

import utils.toy.multi_scattering_generator as multi_scattering
# import utils.state_vector_machine.hamiltonian.hamiltonian.simple_hamiltonian as hamiltonian


import utils.state_vector_machine.state_event_generator.state_event_generator as seg 
import utils.state_vector_machine.state_event_model.state_event_model as state_event_model


import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # State vector generator

# %%
Detector = seg.PlaneGeometry(module_id=[1,2,3],lx = [10,10,10],ly = [10,10,10],z = [10,20,30])

# %%
[i for i in Detector]
# Out:
# [(1, 10, 10, 10), (2, 10, 10, 20), (3, 10, 10, 30)]

# %%
state_event_gen = seg.StateEventGenerator(Detector, events = 5, n_particles=[5,5,2,2,6])
primary_vertices = state_event_gen.generate_random_primary_vertices(10, {'x': 1e-3, 'y': 1e-3, 'z': 1e-3})
print(primary_vertices)
# Out:
# [(0.0003719576507186103, 0.0012887941845938524, 0.00010624558490294442), (0.000639364268642954, 0.00033153347630335826, -0.0018181456859747505), (0.00014367141874084492, 0.0012160552761604298, 0.0008047383739288334), (-0.0009470711882365528, 0.0005800003045662383, -0.0005340059269805858), (0.001995719471284682, -0.0018991995087214043, -0.0008957201062393701)]

# %%
events = 5
n_particles = 20

event_particles = []
for event in range(events):
    particles_list = []
    for particle in range(n_particles):
        particle_dict = {
            'type' : 'electron',
            'mass': 0.511,
            'q': 1
        }
        particles_list.append(particle_dict)
    event_particles.append(particles_list)

print(event_particles)
# Out:
# [[{'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}], [{'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}], [{'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}], [{'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}], [{'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0 ...

# %%
state_event_gen.generate_particles(event_particles)
# Out:
# [[{'type': 'electron',
#    'x': 0.0003719576507186103,
#    'y': 0.0012887941845938524,
#    'z': 0.00010624558490294442,
#    'tx': np.float64(0.09880144383057508),
#    'ty': np.float64(-0.03029023769594685),
#    'p/q': np.float64(0.45721195312353285)},
#   {'type': 'electron',
#    'x': 0.0003719576507186103,
#    'y': 0.0012887941845938524,
#    'z': 0.00010624558490294442,
#    'tx': np.float64(-0.12519436151037844),
#    'ty': np.float64(0.1272507552414967),
#    'p/q': np.float64(0.46197943000945724)},
#   {'type': 'electron',
#    'x': 0.0003719576507186103,
#    'y': 0.0012887941845938524,
#    'z': 0.00010624558490294442,
#    'tx': np.float64(0.12581786312531265),
#    'ty': np.float64(-0.11176314247477452),
#    'p/q': np.float64(0.46118512128083766)},
#   {'type': 'electron',
#    'x': 0.0003719576507186103,
#    'y': 0.0012887941845938524,
#    'z': 0.00010624558490294442,
#    'tx': np.float64(-0.06617435101903603),
#    'ty': np.float64(0.0919659126327315),
#    'p/q': np.float64(0.4576997101359545)},
#   {'type': 'electron',
#    'x': 0.0003719576507186103,
#    'y': 0.0012887941845938524,
#    'z': 0.00010624558490294442,
#    'tx': np.float64(-0.015298497895558765),
#    'ty': np.float64(-0.020570360958686425),
#    'p/q': np.float64(0.4549394157630614)}],
#  [{'type': 'electron',
#    'x': 0.000639364268642954,
#    'y': 0.00033153347630335826,
#    'z': -0.0018181456859747505,
#    'tx': np.float64(-0.01825359731619246),
#    'ty': np.float64(-0.00952868490595018),
#    'p/q': np.float64(0.45488640290931737)},
#   {'type': 'electron',
#    'x': 0.000639364268642954,
#    'y': 0.00033153347630335826,
#    'z': -0.0018181456859747505,
#    'tx': np.float64(-0.1304786809203628),
#    'ty': np.float64(-0.011682893612304814),
#    'p/q': np.float64(0.45867576549700634)},
#   {'type': 'electron',
#    'x': 0.000639364268642954,
#    'y': 0.00033153347630335826,
#    'z': -0.0018181456859747505,
#    'tx': np.float64(0.0045814221346299295),
#    'ty': np.float64(-0.11230955525443898),
#    'p/q': np.float64(0.45765398740154956)},
#   {'type': 'electron',
#    'x': 0.000639364268642954,
#    'y': 0.00033153347630335826,
#    'z': -0.0018181456859747505,
#    'tx': np.float64(-0.05504660209197692),
#    'ty': np.float64(0.05268875402629933),
#    'p/q': np.float64(0.45610839743824294)},
#   {'type': 'electron',
#    'x': 0.000639364268642954,
#    'y': 0.00033153347630335826,
#    'z': -0.0018181456859747505,
#    'tx': np.float64(0.08469945374503228),
#    'ty': np.float64(-0.005012490223230881),
#    'p/q': np.float64(0.45642410870316646)}],
#  [{'type': 'electron',
#    'x': 0.00014367141874084492,
#    'y': 0.0012160552761604298,
#    'z': 0.0008047383739288334,
#    'tx': np.float64(-0.028368619834429887),
#    'ty': np.float64(-0.08416996916727797),
#    'p/q': np.float64(0.4565804770477329)},
#   {'type': 'electron',
#    'x': 0.00014367141874084492,
#    'y': 0.0012160552761604298,
#    'z': 0.0008047383739288334,
#    'tx': np.float64(0.07057265367141663),
#    'ty': np.float64(0.023898715086751725),
#    'p/q': np.float64(0.4560506697266192)}],
#  [{'type': 'electron',
#    'x': -0.0009470711882365528,
#    'y': 0.0005800003045662383,
#    'z': -0.0005340059269805858,
#    'tx': np.float64(-0.06019213349208476),
#    'ty': np.float64(-0.11348298842467565),
#    'p/q': np.float64(0.4585270009737921)},
#   {'type': 'electron',
#    'x': -0.0009470711882365528,
#    'y': 0.0005800003045662383,
#    'z': -0.0005340059269805858,
#    'tx': np.float64(0.0066925354229584975),
#    'ty': np.float64(-0.058292860475990825),
#    'p/q': np.float64(0.45557221365081446)}],
#  [{'type': 'electron',
#    'x': 0.001995719471284682,
#    'y': -0.0018991995087214043,
#    'z': -0.0008957201062393701,
#    'tx': np.float64(-0.11396719468524324),
#    'ty': np.float64(-0.127478333687807),
#    'p/q': np.float64(0.4613909544892906)},
#   {'type': 'electron',
#    'x': 0.001995719471284682,
#    'y': -0.0018991995087214043,
#    'z': -0.0008957201062393701,
#    'tx': np.float64(0.1007052830195663),
#    'ty': np.float64(-0.07769857388343174),
#    'p/q': np.float64(0.4584541769724535)},
#   {'type': 'electron',
#    'x': 0.001995719471284682,
#    'y': -0.0018991995087214043,
#    'z': -0.0008957201062393701,
#    'tx': np.float64(0.11017418635064592),
#    'ty': np.float64(0.08052335351831694),
#    'p/q': np.float64(0.45900509870754463)},
#   {'type': 'electron',
#    'x': 0.001995719471284682,
#    'y': -0.0018991995087214043,
#    'z': -0.0008957201062393701,
#    'tx': np.float64(0.03365691334471683),
#    'ty': np.float64(-0.08494273321228998),
#    'p/q': np.float64(0.4566843607948213)},
#   {'type': 'electron',
#    'x': 0.001995719471284682,
#    'y': -0.0018991995087214043,
#    'z': -0.0008957201062393701,
#    'tx': np.float64(0.018916794634634485),
#    'ty': np.float64(-0.040006966286812363),
#    'p/q': np.float64(0.45523511310877024)},
#   {'type': 'electron',
#    'x': 0.001995719471284682,
#    'y': -0.0018991995087214043,
#    'z': -0.0008957201062393701,
#    'tx': np.float64(0.012542204973789155),
#    'ty': np.float64(0.015418539169438894),
#    'p/q': np.float64(0.4548798208543679)}]]

# %%
event_tracks = state_event_gen.generate_complete_events()

# %%
event_tracks
# Out:
# Event(detector_geometry=PlaneGeometry(module_id=[1, 2, 3], lx=[10, 10, 10], ly=[10, 10, 10], z=[10, 20, 30]), tracks=[[Track(track_id=0, hits=[Hit(hit_id=0, x=np.float64(-0.9967648361684284), y=np.float64(-1.5297390179180663), z=10, module_id=1, track_id=0), Hit(hit_id=1, x=np.float64(1.3295204793754851), y=np.float64(-2.6847698566564056), z=20, module_id=2, track_id=0), Hit(hit_id=2, x=np.float64(5.307222657314376), y=np.float64(-4.263107667280648), z=30, module_id=3, track_id=0)], segments=[Segment(segment_id=0, hits=[Hit(hit_id=0, x=np.float64(-0.9967648361684284), y=np.float64(-1.5297390179180663), z=10, module_id=1, track_id=0), Hit(hit_id=1, x=np.float64(1.3295204793754851), y=np.float64(-2.6847698566564056), z=20, module_id=2, track_id=0)]), Segment(segment_id=1, hits=[Hit(hit_id=1, x=np.float64(1.3295204793754851), y=np.float64(-2.6847698566564056), z=20, module_id=2, track_id=0), Hit(hit_id=2, x=np.float64(5.307222657314376), y=np.float64(-4.263107667280648), z=30, module_id=3, track_id=0)])]), Track(track_id=1, hits=[Hit(hit_id=3, x=np.float64(-0.17356309009476245), y=np.float64(1.4849264954749362), z=10, module_id=1, track_id=1), Hit(hit_id=4, x=np.float64(-4.170882396180575), y=np.float64(4.486347145888567), z=20, module_id=2, track_id=1), Hit(hit_id=5, x=np.float64(-8.615992686192778), y=np.float64(10.445674248993164), z=30, module_id=3, track_id=1)], segments=[Segment(segment_id=0, hits=[Hit(hit_id=3, x=np.float64(-0.17356309009476245), y=np.float64(1.4849264954749362), z=10, module_id=1, track_id=1), Hit(hit_id=4, x=np.float64(-4.170882396180575), y=np.float64(4.486347145888567), z=20, module_id=2, track_id=1)]), Segment(segment_id=1, hits=[Hit(hit_id=4, x=np.float64(-4.170882396180575), y=np.float64(4.486347145888567), z=20, module_id=2, track_id=1), Hit(hit_id=5, x=np.float64(-8.615992686192778), y=np.float64(10.445674248993164), z=30, module_id=3, track_id=1)])]), Track(track_id=2, hits=[Hit(hit_id=6, x=np.float64(0.7776019332158127), y=np.float64(-1.428870506971852), z=10, module_id=1, track_id=2), Hit(hit_id=7, x=np.float64(3.1690632049056817), y=np.float64(-3.8651805483455868), z=20, module_id=2, track_id=2), Hit(hit_id=8, x=np.float64(9.18099599459299), y=np.float64(-7.599605798956245), z=30, module_id=3, track_id=2)], segments=[Segment(segment_id=0, hits=[Hit(hit_id=6, x=np.float64(0.7776019332158127), y=np.float64(-1.428870506971852), z=10, module_id=1, track_id=2), Hit(hit_id=7, x=np.float64(3.1690632049056817), y=np.float64(-3.8651805483455868), z=20, module_id=2, track_id=2)]), Segment(segment_id=1, hits=[Hit(hit_id=7, x=np.float64(3.1690632049056817), y=np.float64(-3.8651805483455868), z=20, module_id=2, track_id=2), Hit(hit_id=8, x=np.float64(9.18099599459299), y=np.float64(-7.599605798956245), z=30, module_id=3, track_id=2)])]), Track(track_id=3, hits=[Hit(hit_id=9, x=np.float64(0.26843303484255254), y=np.float64(1.7479112779867405), z=10, module_id=1, track_id=3), Hit(hit_id=10, x=np.float64(-1.1800617662898396), y=np.float64(3.0676605304181894), z=20, module_id=2, track_id=3), Hit(hit_id=11, x=np.float64(-1.6331567549972126), y=np.float64(6.537010474574938), z=30, module_id=3, track_id=3)], segments=[Segment(segment_id=0, hits=[Hit(hit_id=9, x=np.float64(0.26843303484255254), y=np.float64(1.7479112779867405), z=10, module_id=1, track_id=3), Hit(hit_id=10, x=np.float64(-1.1800617662898396), y=np.float64(3.0676605304181894), z=20, module_id=2, track_id=3)]), Segment(segment_id=1, hits=[Hit(hit_id=10, x=np.float64(-1.1800617662898396), y=np.float64(3.0676605304181894), z=20, module_id=2, track_id=3), Hit(hit_id=11, x=np.float64(-1.6331567549972126), y=np.float64(6.537010474574938), z=30, module_id=3, track_id=3)])]), Track(track_id=4, hits=[Hit(hit_id=12, x=np.float64(-0.26347132015063385), y=np.float64(-0.11242399100430853), z=10, module_id=1, track_id=4), Hit(hit_id=13, x=np.float64(-0.20363144945234135), y=np.float64(-0.16689791773391893), z=20, module_id=2, track_id=4), Hit(hit_id=14, x=np.floa ...

# %%
event_tracks.detector_geometry
# Out:
# PlaneGeometry(module_id=[1, 2, 3], lx=[10, 10, 10], ly=[10, 10, 10], z=[10, 20, 30])

# %%
event_tracks.plot_segments()
# Out:
# PlaneGeometry(module_id=[1, 2, 3], lx=[10, 10, 10], ly=[10, 10, 10], z=[10, 20, 30])

# %%
state_event_gen.hits
# Out:
# [Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19)]

# %%
event_tracks.plot_segments()
# Out:
# PlaneGeometry(module_id=[1, 2, 3], lx=[10, 10, 10], ly=[10, 10, 10], z=[10, 20, 30])

# %% [markdown]
# ### Creating the hamiltonian
