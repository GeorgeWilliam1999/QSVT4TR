# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')

from LHCB_Velo_Toy_Models.state_event_model import *
from LHCB_Velo_Toy_Models.state_event_generator import *
from LHCB_Velo_Toy_Models.multi_scattering_generator import *


# import utils.state_vector_machine.hamiltonian.hamiltonian.simple_hamiltonian as hamiltonian


# import LHCB_Velo_Toy_Models.state_event_generator as seg 
# import LHCB_Velo_Toy_Models.state_event_model as state_event_model


import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # State vector generator

# %%
Detector = PlaneGeometry(module_id=[1,2,3],lx = [10,10,10],ly = [10,10,10],z = [10,20,30])

# %%
[i for i in Detector]
# Out:
# [(1, 10, 10, 10), (2, 10, 10, 20), (3, 10, 10, 30)]

# %%
state_event_gen = StateEventGenerator(Detector, events = 5, n_particles=[5,5,2,2,6])
primary_vertices = state_event_gen.generate_random_primary_vertices(10, {'x': 1e-3, 'y': 1e-3, 'z': 1e-3})
print(primary_vertices)
# Out:
# [(0.0006822062874322166, -0.0005220676841337153, 0.001051607823153919), (-0.00023434114854532217, 0.0007298647710066187, 0.0006178680340874546), (0.0008197821328622013, -0.0018858064335313446, -0.000940554018577786), (-0.0007916546944363299, 0.0006157073134562736, 0.001783051220015972), (-0.0013439453711662028, -0.0006569643246411647, 0.0011307810645274164)]

# %%
events = 5
n_particles = 20

event_particles = []
for event in range(events):
    particles_list = []
    for particle in range(n_particles):
        particle_dict = {
            'type' : 'electron',
            'mass': 0.511,
            'q': 1
        }
        particles_list.append(particle_dict)
    event_particles.append(particles_list)

print(event_particles)
# Out:
# [[{'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}], [{'type': 'electron', 'mass': 0.511, 'q': 1}, {'type': 'electron', 'mass': 0.511, 'q': 1}, {'ty
# ...

# %%
state_event_gen.generate_particles(event_particles)
# Out:
# [[{'type': 'electron',
#    'x': 0.0006822062874322166,
#    'y': -0.0005220676841337153,
#    'z': 0.001051607823153919,
#    'tx': np.float64(-0.09055269563755805),
#    'ty': np.float64(-0.0197852656606739),
#    'p/q': np.float64(0.45673942865658823)},
#   {'type': 'electron',
#    'x': 0.0006822062874322166,
#    'y': -0.0005220676841337153,
#    'z': 0.001051607823153919,
#    'tx': np.float64(-0.0929204979804396),
#    'ty': np.float64(-0.10947636635644023),
#    'p/q': np.float64(0.45945480076703815)},
#   {'type': 'electron',
#    'x': 0.0006822062874322166,
#    'y': -0.0005220676841337153,
#    'z': 0.001051607823153919,
#    'tx': np.float64(-0.05876156954473268),
#    'ty': np.float64(0.07377549135919328),
#    'p/q': np.float64(0.4568083691893381)},
#   {'type': 'electron',
#    'x': 0.0006822062874322166,
#    'y': -0.0005220676841337153,
#    'z': 0.001051607823153919,
#    'tx': np.float64(-0.043154086721092506),
#    'ty': np.float64(0.09625506513200761),
# ...

# %%
event_tracks = state_event_gen.generate_complete_events()

# %%
event_tracks.plot_segments()
# Out:
# PlaneGeometry(module_id=[1, 2, 3], lx=[10, 10, 10], ly=[10, 10, 10], z=[10, 20, 30])

# %%
state_event_gen.hits
# Out:
# [Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
#  Hit(hit_id=59, x=np.float64(2.301083792370491), y=np.float64(1.652833408738343), z=30, module_id=3, track_id=19),
# ...

# %%
event_tracks.plot_segments()
# Out:
# PlaneGeometry(module_id=[1, 2, 3], lx=[10, 10, 10], ly=[10, 10, 10], z=[10, 20, 30])

# %% [markdown]
# ### Creating the hamiltonian
